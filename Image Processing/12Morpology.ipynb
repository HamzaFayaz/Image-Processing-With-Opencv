# %% [markdown]
# 1) Morpology : adjusted the pixel value base on the values of neighborhood (Using Kernel for this  or strucature Elements (check of this E))
#
#
# 2) Dilation :  it perform (# OR opretion like method  ) set the  new pixel true if only pixel in (direct or kernel) are true and other to false
#   ![image.png](attachment:image.png)
#
#
#
# 3) Erosion : it perform (# AND opretion like method  ) set the  new pixel true if ALL pixel in (direct or kernel) are true and other to false
#
#     ![alt text](image-6.png)
#
#
# 4) Morpological closing:
#
#    Dilation -----> Erosion
#
# 5) MorPological opening :
#
#     Erosion --------> Dilation
#
# 6) gradiant  operation
#   dilation - erosion
#   ![alt text](image-7.png)
#
# 7) Top hat
#   input image -  MorPological opening
#   use to get the small details in image mask
#   ![alt text](image-8.png)
#
# 8) Black hat
#   closing - input iamge
#   to get the large details in image
#   ![alt text](image-9.png)

# %% [markdown]
# # Now Strat Coding
#
# ![alt text](image-10.png)
